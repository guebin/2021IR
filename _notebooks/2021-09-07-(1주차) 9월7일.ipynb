# %% [markdown]
# # (1주차) 9월7일
# > 2005년 예비평가(나) 12월/평가원26(고3) 문제풀이
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 최규빈

# %%
#hide
options(jupyter.plot_scale=3)
options(jupyter.display_mimetypes=c("text/html"))
options(jupyter.rich_display=FALSE)
options(repr.plot.width=6,repr.plot.height=6,repr.plot.res=300)
options(max.print=1000)

# %% [markdown]
# ### 강의영상

# %% [markdown]
# > youtube: https://youtube.com/playlist?list=PLQqh36zP38-xdu76U7HLplMcg9s6giDH3

# %% [markdown]
# `-` (1/2): 2005년 예비평가(나) 12월/평가원26(고3) 첫번째 풀이
#
# `-` (2/2): 2005년 예비평가(나) 12월/평가원26(고3) 다양한 풀이 + 과제설명

# %% [markdown]
# ### R은 좋은 계산기 이다.

# %% [markdown]
# #### 2005년 예비평가(나) 12월/평가원26(고3)

# %% [markdown]
# 어떤 호수에서 수면에서의 빛의 세기가 $I_0$일 때, 수면이 $d$m인 곳에서의 빛의 세기 $I_d$는 다음과 같이 나타내어진다고 한다.

# %% [markdown]
# $$I_d=I_0 2^{-0.25d}$$

# %% [markdown]
# 이 호수에서 빛의 세기가 수면에서의 빛의 세기의 25%인 곳의 수심은? (3점)

# %% [markdown]
# (1) 16m
#
# (2) 12m
#
# (3) 10m
#
# (4) 8m
#
# (5) 4m

# %% [markdown]
# (풀이1)

# %%
I0=1
d=8
Id=I0*0.25

# %%
I0*2^(-0.25*d) ## 0.25 랑 비슷하면 된다. 현재는 Id=0.25니까..
# Out:
# [1] 0.25

# %% [markdown]
# (풀이2)

# %%
d=8
y=I0*2^(-0.25*d)/Id
y
# Out:
# [1] 1

# %% [markdown]
# `-` $y=1$이 나오는 $d$를 찾아보면된다. $\to$ 찾아보니까 $d=8$

# %% [markdown]
# (풀이3)

# %% [markdown]
# `-` 함수라는걸 만들어보자.

# %% [markdown]
# `-` $d$를 입력하면, 알아서 $y$가 계산되면 좋겠다.

# %% [markdown]
# $$y=f(d)$$

# %%
f<-function(d){
    y=I0*2^(-0.25*d)/Id
    y
}

# %% [markdown]
# `-` $y=f(d)=\frac{I_0 2^{-0.25 d}}{I_d}$ 를 함수를 만들자.
#
# `-` $y=1$이 되는 $d$를 찾아보자. 그러면 답이다.

# %%
f(8)
# Out:
# [1] 1

# %% [markdown]
# `-` $d=8$이 답이다.

# %% [markdown]
# (풀이4)

# %% [markdown]
# `-` $(d,f(d))$ 혹은 $(d,y)$를 그래프로 그려보자.

# %%
d<-c(1,2,3)

# %%
d<-seq(from=0,to=10,by=0.01)

# %%
y=I0*2^(-0.25*d)/Id

# %%
plot(d,y)
# Out:
# plot without title

# %%
plot(d,y)
abline(h=1,col=2,lwd=5,lty=3)
# Out:
# plot without title

# %% [markdown]
# (풀이5)

# %%
x_<-c(1,2,3,2,5)

# %%
x_ == 3
# Out:
# [1] FALSE FALSE  TRUE FALSE FALSE

# %%
d[y==1]
# Out:
# [1] 8

# %% [markdown]
# ### [숙제](https://ieilms.jbnu.ac.kr/)

# %% [markdown]
# `-` 아래그림에서 수평선의 위치를 $y=2$로 조정하여 그려볼것

# %%
plot(d,y)
abline(h=1.1,col=2,lwd=5,lty=3)
# Out:
# plot without title
